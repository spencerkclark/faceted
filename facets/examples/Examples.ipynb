# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

from facets.facets import BasicGrid, ColorbarGrid, MultiColorbarGrid

# %matplotlib inline

# %%
bg = BasicGrid(2, 3, width_constraint=8., aspect=0.6,
               internal_pad=0.2, top_pad=0.5,
               bottom_pad=0.5, left_pad=0.5, 
               right_pad=0.5)
fig = bg.fig
axes = bg.axes()

x = np.linspace(0., 6. * np.pi)
y = np.sin(x)

for ax in axes:
    ax.plot(x, y)
    ax.set_yticks(np.arange(-1., 1.2, 0.5))
    ax.set_xticks(np.arange(0., 18.1, 3.))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
axes[0].set_yticklabels(np.arange(-1., 1.2, 0.5))
axes[3].set_yticklabels(np.arange(-1., 1.2, 0.5))

axes[3].set_xticklabels(np.arange(0., 18.1, 3.))
axes[4].set_xticklabels(np.arange(0., 18.1, 3.))
axes[5].set_xticklabels(np.arange(0., 18.1, 3.))

fig.savefig('basic-grid-example.pdf')

# %%
cg = ColorbarGrid(
    2, 3, width_constraint=8., 
    internal_pad=0.2, top_pad=0.5,
    bottom_pad=0.5, left_pad=0.5, right_pad=1., 
    long_side_pad=0.1, short_side_pad=0.1, cbar_location='right')

fig = cg.fig
axes, cax = cg.axes()

x = np.linspace(0., 6. * np.pi)
y = np.linspace(0., 6. * np.pi)
xg, yg = np.meshgrid(x, y)
z = np.sin(xg) * np.cos(yg)
levels = np.arange(-1., 1.05, 0.1)

for ax in axes:
    ax.contourf(x, y, z, levels=levels, cmap='RdBu_r')
    ax.set_yticks(np.arange(0., 18.1, 6.))
    ax.set_xticks(np.arange(0., 18.1, 6.))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
axes[0].set_yticklabels(np.arange(0., 18.1, 6.))
axes[3].set_yticklabels(np.arange(0., 18.1, 6.))

axes[3].set_xticklabels(np.arange(0., 18.1, 6.))
axes[4].set_xticklabels(np.arange(0., 18.1, 6.))
axes[5].set_xticklabels(np.arange(0., 18.1, 6.))

cmap = mpl.cm.RdBu_r
cbar = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                 boundaries=levels,
                                 orientation='vertical')
cbar.set_label('Example')

fig.savefig('colorbar-grid-example.pdf')

# %%
mcg = MultiColorbarGrid(
    2, 3, width_constraint=8., 
    internal_pad=0.7, top_pad=0.5,
    bottom_pad=0.5, left_pad=0.5, right_pad=0.5, 
    long_side_pad=0.1, short_side_pad=0.0, cbar_location='right')

fig = mcg.fig
axes, caxes = mcg.axes()

x = np.linspace(0., 6. * np.pi)
y = np.linspace(0., 6. * np.pi)
xg, yg = np.meshgrid(x, y)
z = np.sin(xg) * np.cos(yg)
levels = np.arange(-1., 1.05, 0.1)

for ax in axes:
    ax.contourf(x, y, z, levels=levels, cmap='RdBu_r')
    ax.set_yticks(np.arange(0., 18.1, 6.))
    ax.set_xticks(np.arange(0., 18.1, 6.))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
axes[0].set_yticklabels(np.arange(0., 18.1, 6.))
axes[3].set_yticklabels(np.arange(0., 18.1, 6.))

axes[3].set_xticklabels(np.arange(0., 18.1, 6.))
axes[4].set_xticklabels(np.arange(0., 18.1, 6.))
axes[5].set_xticklabels(np.arange(0., 18.1, 6.))

for cax in caxes:
    cmap = mpl.cm.RdBu_r
    cbar = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                     boundaries=levels,
                                     orientation='vertical')
    cbar.set_label('Example')
    cbar.set_ticks(np.arange(-1., 1.01, 0.5))
    
fig.savefig('multi-colorbar-grid-example.pdf')

# %%
mcg = MultiColorbarGrid(
    2, 3, width_constraint=8., 
    internal_pad=0.5, top_pad=0.5,
    bottom_pad=0.5, left_pad=0.5, right_pad=0.5, 
    long_side_pad=0.3, short_side_pad=0.0, cbar_location='bottom')

fig = mcg.fig
axes, caxes = mcg.axes()

x = np.linspace(0., 6. * np.pi)
y = np.linspace(0., 6. * np.pi)
xg, yg = np.meshgrid(x, y)
z = np.sin(xg) * np.cos(yg)
levels = np.arange(-1., 1.05, 0.1)

for ax in axes:
    ax.contourf(x, y, z, levels=levels, cmap='RdBu_r')
    ax.set_yticks(np.arange(0., 18.1, 6.))
    ax.set_xticks(np.arange(0., 18.1, 6.))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
axes[0].set_yticklabels(np.arange(0., 18.1, 6.))
axes[3].set_yticklabels(np.arange(0., 18.1, 6.))

axes[3].set_xticklabels(np.arange(0., 18.1, 6.))
axes[4].set_xticklabels(np.arange(0., 18.1, 6.))
axes[5].set_xticklabels(np.arange(0., 18.1, 6.))

for cax in caxes:
    cmap = mpl.cm.RdBu_r
    cbar = mpl.colorbar.ColorbarBase(cax, cmap=cmap,
                                     boundaries=levels,
                                     orientation='horizontal')
    cbar.set_label('Example')
    cbar.set_ticks(np.arange(-1., 1.01, 0.5))
    
fig.savefig('multi-colorbar-grid-example.pdf')
